# %%
import pandas as pd

# %%
data_dict = {'6 AM' : 0 , '7 AM' : 4, '8 AM' : 5 ,'9 AM' : 5 ,'10 AM' : 5 ,
             '11 AM' : 5 ,'12 PM' : 4 ,'01 PM' : 1 ,'02 PM' : 3 ,'03 PM' : 4 ,'04 PM' : 4 ,
             '05 PM' : 0 ,'06 PM' : 5 ,'07 PM' : 4 ,
             '08 PM' : 3 ,'09 PM' : 4 ,'10 PM' : 5 ,'11 PM' : 2 }

# %%
keys = []
values = []
for i in data_dict:
    keys.append(i)
    values.append(data_dict[i])

# %%
keys
# Out:
# ['6 AM',
#  '7 AM',
#  '8 AM',
#  '9 AM',
#  '10 AM',
#  '11 AM',
#  '12 PM',
#  '01 PM',
#  '02 PM',
#  '03 PM',
#  '04 PM',
#  '05 PM',
#  '06 PM',
#  '07 PM',
#  '08 PM',
#  '09 PM',
#  '10 PM',
#  '11 PM']

# %%
values
# Out:
# [0, 4, 5, 5, 5, 5, 4, 1, 3, 4, 4, 0, 5, 4, 3, 4, 5, 2]

# %%
data = pd.DataFrame(values,index=keys,columns=['Productivity'])

# %%
data.head()
# Out:
#        Productivity
# 6 AM              0
# 7 AM              4
# 8 AM              5
# 9 AM              5
# 10 AM             5

# %%
data.plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,8),dpi=80)
plt.barh(data.index,data.Productivity,color = 'g',alpha = 0.8)
plt.grid(color = 'grey',alpha = 0.1)
plt.xlabel('Time',color = 'red',size = 20,style = 'oblique')
plt.ylabel('Productivity',color = 'red',size = 20,style = 'oblique')
plt.xticks(color = 'white',size = 13)
plt.yticks(color = 'white',size = 13)
plt.title('PRODUCTIVITY ANALYSIS',color = 'red',size = 30,style = 'normal')
plt.show()
