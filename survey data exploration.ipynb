# %%
import pandas as pd
# Out:
# /home/Nithish1201/DataScience/DataScienceEnv/lib/python3.8/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv('survey_data.csv')
df.head()
# Out:
#              Timestamp          Name    Age  LED usg         Student  \
# 0  08/07/2021 12:02:27       nithish  18-23        8  under-graduate
# 1  08/07/2021 14:38:06  Rithani K. S  18-23        2  under-graduate
# 2  08/07/2021 14:38:58       Mythili  18-23        5  under-graduate
# 3  08/07/2021 14:41:07    kushal sai  18-23        8  under-graduate
# 4  08/07/2021 14:42:18          Neil  18-23        8  under-graduate
#
#    Academics  Mbl usg  Lap usg  Pc usg  Tab usg  TV usg Other  Education pps  \
# 0          4        2        8       0        0       1   NaN              9
# 1          4        6        2       0        0       1   No               8
# 2          4        5        1       0        1       1   NaN              3
# 3          3        5        4       0        0       1  None              2
# 4          4        4        4       0        0       1   NaN              3
#
#    work pps  Timepass pps  Gaming pss     Other.1 Eye problem power glass  \
# ...

# %%
data = df.drop(['Other','Other.1'],axis=1)
data.head()
# Out:
#              Timestamp          Name    Age  LED usg         Student  \
# 0  08/07/2021 12:02:27       nithish  18-23        8  under-graduate
# 1  08/07/2021 14:38:06  Rithani K. S  18-23        2  under-graduate
# 2  08/07/2021 14:38:58       Mythili  18-23        5  under-graduate
# 3  08/07/2021 14:41:07    kushal sai  18-23        8  under-graduate
# 4  08/07/2021 14:42:18          Neil  18-23        8  under-graduate
#
#    Academics  Mbl usg  Lap usg  Pc usg  Tab usg  TV usg  Education pps  \
# 0          4        2        8       0        0       1              9
# 1          4        6        2       0        0       1              8
# 2          4        5        1       0        1       1              3
# 3          3        5        4       0        0       1              2
# 4          4        4        4       0        0       1              3
#
#    work pps  Timepass pps  Gaming pss Eye problem power glass     headaches
# ...

# %%
med_data = data[['Eye problem','power glass','headaches']]
med_data
# Out:
#    Eye problem power glass     headaches
# 0          Yes         Yes        Rarely
# 1           No          No  NO headaches
# 2        Maybe          No        Rarely
# 3          Yes         Yes        Weekly
# 4          Yes         Yes        Rarely
# ..         ...         ...           ...
# 92       Maybe          No        Rarely
# 93         Yes         Yes        Rarely
# 94         Yes       Maybe       Monthly
# 95          No          No  NO headaches
# 96          No          No  NO headaches
#
# [97 rows x 3 columns]

# %%
data.describe()
# Out:
#          LED usg  Academics    Mbl usg    Lap usg     Pc usg    Tab usg  \
# count  97.000000  97.000000  97.000000  97.000000  97.000000  97.000000
# mean    7.371134   3.659794   6.505155   2.463918   0.432990   0.536082
# std     2.053044   0.627273   2.578451   2.432685   1.533699   1.346770
# min     2.000000   3.000000   1.000000   0.000000   0.000000   0.000000
# 25%     6.000000   3.000000   5.000000   0.000000   0.000000   0.000000
# 50%     8.000000   4.000000   7.000000   2.000000   0.000000   0.000000
# 75%     9.000000   4.000000   8.000000   4.000000   0.000000   0.000000
# max    10.000000   5.000000  10.000000  10.000000  10.000000   8.000000
#
#           TV usg  Education pps   work pps  Timepass pps  Gaming pss
# count  97.000000      97.000000  97.000000     97.000000   97.000000
# mean    1.536082       4.969072   2.061856      3.381443    1.103093
# std     1.750368       2.412872   2.448700      2.200584    1.734962
# ...

# %%
data.shape
# Out:
# (97, 18)

# %%
data.columns
# Out:
# Index(['Timestamp', 'Name', 'Age', 'LED usg', 'Student', 'Academics',
#        'Mbl usg', 'Lap usg', 'Pc usg', 'Tab usg', 'TV usg', 'Education pps',
#        'work pps', 'Timepass pps', 'Gaming pss', 'Eye problem', 'power glass',
#        'headaches'],
#       dtype='object')

# %%
data.isnull().any()
# Out:
# Timestamp        False
# Name             False
# Age              False
# LED usg          False
# Student          False
# Academics        False
# Mbl usg          False
# Lap usg          False
# Pc usg           False
# Tab usg          False
# TV usg           False
# Education pps    False
# work pps         False
# Timepass pps     False
# Gaming pss       False
# Eye problem      False
# power glass      False
# headaches        False
# dtype: bool

# %%
data['headaches'].value_counts().to_frame().plot(figsize = (10,6),kind = 'pie',subplots = True)
# Out:
# array([<AxesSubplot:ylabel='headaches'>], dtype=object)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(data['Lap usg'],data['Academics'],'o')
plt.xticks(0,)
plt.xlabel('Laptop usage')
plt.ylabel('Acadamic performances')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('survey_data.csv')
data.head()
# Out:
#              Timestamp          Name    Age  LED usg         Student  \
# 0  08/07/2021 12:02:27       nithish  18-23        8  under-graduate
# 1  08/07/2021 14:38:06  Rithani K. S  18-23        2  under-graduate
# 2  08/07/2021 14:38:58       Mythili  18-23        5  under-graduate
# 3  08/07/2021 14:41:07    kushal sai  18-23        8  under-graduate
# 4  08/07/2021 14:42:18          Neil  18-23        8  under-graduate
#
#    Academics  Mbl usg  Lap usg  Pc usg  Tab usg  TV usg Other  Education pps  \
# 0          4        2        8       0        0       1   NaN              9
# 1          4        6        2       0        0       1   No               8
# 2          4        5        1       0        1       1   NaN              3
# 3          3        5        4       0        0       1  None              2
# 4          4        4        4       0        0       1   NaN              3
#
#    work pps  Timepass pps  Gaming pss     Other.1 Eye problem power glass  \
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('survey_data.csv')

plt.figure(figsize=(12,8))
plt.bar(data['Name'].head(10),data['Academics'].head(10),color = 'red',alpha = 0.6)
plt.xticks(color = 'white')
plt.yticks(color = 'white',size = 15)
plt.grid(linewidth = 0.5,alpha = 0.2,color = 'grey')
plt.title('Students Academic Report',color = 'white',size = 30,style = 'oblique')
plt.show()
